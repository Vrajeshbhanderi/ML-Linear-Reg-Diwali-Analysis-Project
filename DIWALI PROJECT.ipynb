# %%
import pandas as pd
import matplotlib.pyplot as mlt
import numpy as np
import seaborn as sns

# %%
 d=pd.read_csv(r'C:\Users\OM ENTERPRISE\Desktop\Python_Diwali_Sales_Analysis\Diwali Sales Data.csv', encoding= 'unicode_escape')

# %%
d.head(1)
# Out:
#    User_ID  Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0  1002903  Sanskriti  P00125942      F     26-35   28               0
#
#          State     Zone  Occupation Product_Category  Orders   Amount  Status  \
# 0  Maharashtra  Western  Healthcare             Auto       1  23952.0     NaN
#
#    unnamed1
# 0       NaN

# %%
d.head()
# Out:
#    User_ID  Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0  1002903  Sanskriti  P00125942      F     26-35   28               0
# 1  1000732     Kartik  P00110942      F     26-35   35               1
# 2  1001990      Bindu  P00118542      F     26-35   35               1
# 3  1001425     Sudevi  P00237842      M      0-17   16               0
# 4  1000588       Joni  P00057942      M     26-35   28               1
#
#             State      Zone       Occupation Product_Category  Orders  \
# 0     Maharashtra   Western       Healthcare             Auto       1
# 1  Andhra Pradesh  Southern             Govt             Auto       3
# 2   Uttar Pradesh   Central       Automobile             Auto       3
# 3       Karnataka  Southern     Construction             Auto       2
# 4         Gujarat   Western  Food Processing             Auto       2
#
#     Amount  Status  unnamed1
# 0  23952.0     NaN       NaN
# 1  23934.0     NaN       NaN
# ...

# %%
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11251 entries, 0 to 11250
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11251 non-null  int64
#  1   Cust_name         11251 non-null  object
#  2   Product_ID        11251 non-null  object
#  3   Gender            11251 non-null  object
#  4   Age Group         11251 non-null  object
#  5   Age               11251 non-null  int64
#  6   Marital_Status    11251 non-null  int64
#  7   State             11251 non-null  object
#  8   Zone              11251 non-null  object
#  9   Occupation        11251 non-null  object
#  10  Product_Category  11251 non-null  object
#  11  Orders            11251 non-null  int64
#  12  Amount            11239 non-null  float64
#  13  Status            0 non-null      float64
#  14  unnamed1          0 non-null      float64
# dtypes: float64(3), int64(4), object(8)
# memory usage: 1.3+ MB

# %%
d.shape
# Out:
# (11251, 15)

# %%
d.drop(["Status","unnamed1"],axis=1,inplace=True)

# %%
d
# Out:
#        User_ID    Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0      1002903    Sanskriti  P00125942      F     26-35   28               0
# 1      1000732       Kartik  P00110942      F     26-35   35               1
# 2      1001990        Bindu  P00118542      F     26-35   35               1
# 3      1001425       Sudevi  P00237842      M      0-17   16               0
# 4      1000588         Joni  P00057942      M     26-35   28               1
# ...        ...          ...        ...    ...       ...  ...             ...
# 11246  1000695      Manning  P00296942      M     18-25   19               1
# 11247  1004089  Reichenbach  P00171342      M     26-35   33               0
# 11248  1001209        Oshin  P00201342      F     36-45   40               0
# 11249  1004023       Noonan  P00059442      M     36-45   37               0
# 11250  1002744      Brumley  P00281742      F     18-25   19               0
#
# ...

# %%
d.isnull().sum()
# Out:
# User_ID              0
# Cust_name            0
# Product_ID           0
# Gender               0
# Age Group            0
# Age                  0
# Marital_Status       0
# State                0
# Zone                 0
# Occupation           0
# Product_Category     0
# Orders               0
# Amount              12
# dtype: int64

# %%
d.dropna(inplace=True)

# %%
d.isnull().sum()
# Out:
# User_ID             0
# Cust_name           0
# Product_ID          0
# Gender              0
# Age Group           0
# Age                 0
# Marital_Status      0
# State               0
# Zone                0
# Occupation          0
# Product_Category    0
# Orders              0
# Amount              0
# dtype: int64

# %%
d
# Out:
#        User_ID    Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0      1002903    Sanskriti  P00125942      F     26-35   28               0
# 1      1000732       Kartik  P00110942      F     26-35   35               1
# 2      1001990        Bindu  P00118542      F     26-35   35               1
# 3      1001425       Sudevi  P00237842      M      0-17   16               0
# 4      1000588         Joni  P00057942      M     26-35   28               1
# ...        ...          ...        ...    ...       ...  ...             ...
# 11246  1000695      Manning  P00296942      M     18-25   19               1
# 11247  1004089  Reichenbach  P00171342      M     26-35   33               0
# 11248  1001209        Oshin  P00201342      F     36-45   40               0
# 11249  1004023       Noonan  P00059442      M     36-45   37               0
# 11250  1002744      Brumley  P00281742      F     18-25   19               0
#
# ...

# %%
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11239 entries, 0 to 11250
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11239 non-null  int64
#  1   Cust_name         11239 non-null  object
#  2   Product_ID        11239 non-null  object
#  3   Gender            11239 non-null  object
#  4   Age Group         11239 non-null  object
#  5   Age               11239 non-null  int64
#  6   Marital_Status    11239 non-null  int64
#  7   State             11239 non-null  object
#  8   Zone              11239 non-null  object
#  9   Occupation        11239 non-null  object
#  10  Product_Category  11239 non-null  object
#  11  Orders            11239 non-null  int64
#  12  Amount            11239 non-null  float64
# dtypes: float64(1), int64(4), object(8)
# memory usage: 1.2+ MB

# %%
d["Amount"]=d["Amount"].astype(int)

# %%
d["Amount"].dtypes
# Out:
# dtype('int32')

# %%
d.describe()
# Out:
#             User_ID           Age  Marital_Status        Orders        Amount
# count  1.123900e+04  11239.000000    11239.000000  11239.000000  11239.000000
# mean   1.003004e+06     35.410357        0.420055      2.489634   9453.610553
# std    1.716039e+03     12.753866        0.493589      1.114967   5222.355168
# min    1.000001e+06     12.000000        0.000000      1.000000    188.000000
# 25%    1.001492e+06     27.000000        0.000000      2.000000   5443.000000
# 50%    1.003064e+06     33.000000        0.000000      2.000000   8109.000000
# 75%    1.004426e+06     43.000000        1.000000      3.000000  12675.000000
# max    1.006040e+06     92.000000        1.000000      4.000000  23952.000000

# %%
#eda

# %%
ax=sns.countplot(x='Gender',data=d)

for bars in ax.containers:
    ax.bar_label(bars)

# %%
d.head()
# Out:
#    User_ID  Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0  1002903  Sanskriti  P00125942      F     26-35   28               0
# 1  1000732     Kartik  P00110942      F     26-35   35               1
# 2  1001990      Bindu  P00118542      F     26-35   35               1
# 3  1001425     Sudevi  P00237842      M      0-17   16               0
# 4  1000588       Joni  P00057942      M     26-35   28               1
#
#             State      Zone       Occupation Product_Category  Orders  Amount
# 0     Maharashtra   Western       Healthcare             Auto       1   23952
# 1  Andhra Pradesh  Southern             Govt             Auto       3   23934
# 2   Uttar Pradesh   Central       Automobile             Auto       3   23924
# 3       Karnataka  Southern     Construction             Auto       2   23912
# 4         Gujarat   Western  Food Processing             Auto       2   23877

# %%
d.drop(["Product_Category"],axis=1,inplace=True)

# %%
d.head()
# Out:
#    User_ID  Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0  1002903  Sanskriti  P00125942      F     26-35   28               0
# 1  1000732     Kartik  P00110942      F     26-35   35               1
# 2  1001990      Bindu  P00118542      F     26-35   35               1
# 3  1001425     Sudevi  P00237842      M      0-17   16               0
# 4  1000588       Joni  P00057942      M     26-35   28               1
#
#             State      Zone       Occupation  Orders  Amount
# 0     Maharashtra   Western       Healthcare       1   23952
# 1  Andhra Pradesh  Southern             Govt       3   23934
# 2   Uttar Pradesh   Central       Automobile       3   23924
# 3       Karnataka  Southern     Construction       2   23912
# 4         Gujarat   Western  Food Processing       2   23877

# %%
d.rename(columns={"Age Group":"Age_Group"},inplace=True)

# %%
d["Age_Group"].unique()
# Out:
# array(['26-35', '0-17', '18-25', '51-55', '46-50', '55+', '36-45'],
#       dtype=object)

# %%
d["Age_Group"].unique()
# Out:
# array(['26-35', '0-17', '18-25', '51-55', '46-50', '55+', '36-45'],
#       dtype=object)

# %%
d.head()
# Out:
#    User_ID  Cust_name Product_ID Gender Age_Group  Age  Marital_Status  \
# 0  1002903  Sanskriti  P00125942      F     26-35   28               0
# 1  1000732     Kartik  P00110942      F     26-35   35               1
# 2  1001990      Bindu  P00118542      F     26-35   35               1
# 3  1001425     Sudevi  P00237842      M      0-17   16               0
# 4  1000588       Joni  P00057942      M     26-35   28               1
#
#             State      Zone       Occupation  Orders  Amount
# 0     Maharashtra   Western       Healthcare       1   23952
# 1  Andhra Pradesh  Southern             Govt       3   23934
# 2   Uttar Pradesh   Central       Automobile       3   23924
# 3       Karnataka  Southern     Construction       2   23912
# 4         Gujarat   Western  Food Processing       2   23877

# %%
d["Cust_name"].value_counts()
# Out:
# Cust_name
# Vishakha       42
# Shreyshi       32
# Sudevi         30
# Akshat         29
# Alejandro      28
#                ..
# Overcash        2
# Madan Mohan     2
# Madhav          2
# Laal            1
# Bindu           1
# Name: count, Length: 1250, dtype: int64

# %%
sales=d.groupby(d["Gender"],as_index=False)["Amount"].sum().sort_values(by="Amount",ascending=False)

# %%
sales=sns.barplot(x='Gender',y='Amount',data=sales)

# %%
age=sns.countplot(data=d,x='Age_Group',hue='Gender')

for bars in age.containers:
    age.bar_label(bars)

# %%
d.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age_Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Orders', 'Amount'],
#       dtype='object')

# %%
age_g=d.groupby(d["Age_Group"],as_index=False)["Amount"].sum().sort_values(by='Amount',ascending=False)

# %%
sns.barplot(x="Age_Group",y="Amount",data=age_g)
# Out:
# <Axes: xlabel='Age_Group', ylabel='Amount'>

# %%
d.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age_Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Orders', 'Amount'],
#       dtype='object')

# %%
o=d.groupby(["State"],as_index=False)["Orders"].sum().sort_values(by='Orders', ascending=False).head(10)
sns.set(rc={'figure.figsize':(17,5)})
O=sns.barplot(x='State',y='Orders',data=o)

for bars in O.containers:
    O.bar_label(bars)

# %%
t=d.groupby(["State"],as_index=False)['Amount'].sum().sort_values(by="Amount",ascending=False).head(10)
sns.set(rc={'figure.figsize':(17,5)})
sns.barplot(x="State",y="Amount",data=t)
# Out:
# <Axes: xlabel='State', ylabel='Amount'>

# %%
occ=sns.countplot(data=d,x="Occupation")
sns.set(rc={'figure.figsize':(20,5)})
for bars in occ.containers:
    occ.bar_label(bars)

# %%
d.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age_Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Orders', 'Amount'],
#       dtype='object')

# %%
M=d.groupby(["Marital_Status"],as_index=False)["Orders"].sum().sort_values(by="Orders",ascending=False)
sns.barplot(x='Marital_Status',y='Orders',hue="Marital_Status",data=M)
sns.set(rc={'figure.figsize':(3,7)})

# %%
d
# Out:
#        User_ID    Cust_name Product_ID Gender Age_Group  Age  Marital_Status  \
# 0      1002903    Sanskriti  P00125942      F     26-35   28               0
# 1      1000732       Kartik  P00110942      F     26-35   35               1
# 2      1001990        Bindu  P00118542      F     26-35   35               1
# 3      1001425       Sudevi  P00237842      M      0-17   16               0
# 4      1000588         Joni  P00057942      M     26-35   28               1
# ...        ...          ...        ...    ...       ...  ...             ...
# 11246  1000695      Manning  P00296942      M     18-25   19               1
# 11247  1004089  Reichenbach  P00171342      M     26-35   33               0
# 11248  1001209        Oshin  P00201342      F     36-45   40               0
# 11249  1004023       Noonan  P00059442      M     36-45   37               0
# 11250  1002744      Brumley  P00281742      F     18-25   19               0
#
# ...

# %%
d.drop("Cust_name",axis=1,inplace=True)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
enc=LabelEncoder()

# %%
d.columns
# Out:
# Index(['User_ID', 'Product_ID', 'Gender', 'Age_Group', 'Age', 'Marital_Status',
#        'State', 'Zone', 'Occupation', 'Orders', 'Amount'],
#       dtype='object')

# %%
d[['User_ID', 'Product_ID', 'Gender', 'Age_Group', 'Age', 'Marital_Status',
       'State', 'Zone', 'Occupation', 'Orders']]=d[['User_ID', 'Product_ID', 'Gender', 'Age_Group', 'Age', 'Marital_Status',
       'State', 'Zone', 'Occupation', 'Orders']].apply(enc.fit_transform)

# %%
d[["Product_ID"]]
# Out:
#        Product_ID
# 0             774
# 1             644
# 2             714
# 3            1507
# 4             387
# ...           ...
# 11246        1888
# 11247        1039
# 11248        1263
# 11249         396
# 11250        1786
#
# [11239 rows x 1 columns]

# %%
d["Product_ID"].value_counts()
# Out:
# Product_ID
# 1679    53
# 644     44
# 1146    37
# 1504    35
# 654     34
#         ..
# 1633     1
# 482      1
# 2099     1
# 1288     1
# 1888     1
# Name: count, Length: 2350, dtype: int64

# %%
d
# Out:
#        User_ID  Product_ID  Gender  Age_Group  Age  Marital_Status  State  \
# 0         1780         774       0          2   16               0     10
# 1          456         644       0          2   23               1      0
# 2         1226         714       0          2   23               1     14
# 3          890        1507       1          0    4               0      7
# 4          371         387       1          2   16               1      3
# ...        ...         ...     ...        ...  ...             ...    ...
# 11246      431        1888       1          1    7               1     10
# 11247     2536        1039       1          2   21               0      4
# 11248      749        1263       0          3   28               0      9
# 11249     2494         396       1          3   25               0      7
# 11250     1672        1786       0          1    7               0     10
#
#        Zone  Occupation  Orders  Amount
# ...

# %%
x=d.drop("Amount",axis=1)
y=d['Amount']

# %%
d
# Out:
#        User_ID  Product_ID  Gender  Age_Group  Age  Marital_Status  State  \
# 0         1780         774       0          2   16               0     10
# 1          456         644       0          2   23               1      0
# 2         1226         714       0          2   23               1     14
# 3          890        1507       1          0    4               0      7
# 4          371         387       1          2   16               1      3
# ...        ...         ...     ...        ...  ...             ...    ...
# 11246      431        1888       1          1    7               1     10
# 11247     2536        1039       1          2   21               0      4
# 11248      749        1263       0          3   28               0      9
# 11249     2494         396       1          3   25               0      7
# 11250     1672        1786       0          1    7               0     10
#
#        Zone  Occupation  Orders  Amount
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.6,random_state=0)

# %%
from sklearn.linear_model import LogisticRegression,

# %%
model=LogisticRegression()

# %%
import warnings 
warnings.filterwarnings("ignore")

# %%
model.fit(x_train,y_train)

# %%
model.score(x_train,y_train)
# Out:
# 0.00217498764211567

# %%
model.score(x_train,y_train)
# Out:
# 0.0028921023359288096

# %%
model.score(x_test,y_test)
# Out:
# 0.0013345195729537367

# %%
from sklearn.linear_model import LinearRegression

# %%
model1=LinearRegression()

# %%
model1.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
model1.score(x_train,y_train)
# Out:
# 0.003044146645046264

# %%
model1.score(x_test,y_test)
# Out:
# -0.007239309648298553

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.4,random_state=0)

# %%
d
# Out:
#        User_ID  Product_ID  Gender  Age_Group  Age  Marital_Status  State  \
# 0         1780         774       0          2   16               0     10
# 1          456         644       0          2   23               1      0
# 2         1226         714       0          2   23               1     14
# 3          890        1507       1          0    4               0      7
# 4          371         387       1          2   16               1      3
# ...        ...         ...     ...        ...  ...             ...    ...
# 11246      431        1888       1          1    7               1     10
# 11247     2536        1039       1          2   21               0      4
# 11248      749        1263       0          3   28               0      9
# 11249     2494         396       1          3   25               0      7
# 11250     1672        1786       0          1    7               0     10
#
#        Zone  Occupation  Orders  Amount
# ...

# %%
d.columns
# Out:
# Index(['User_ID', 'Product_ID', 'Gender', 'Age_Group', 'Age', 'Marital_Status',
#        'State', 'Zone', 'Occupation', 'Orders', 'Amount'],
#       dtype='object')

# %%
plt.pie(d[Amount],autopct='%1.2f%%',labels=d["Age_Group"])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[90], line 1
# ----> 1 plt.pie(d[Amount],autopct='%1.2f%%',labels=d["Age_Group"])
#
# File C:\ProgramData\anaconda3\Lib\site-packages\matplotlib\_api\__init__.py:226, in caching_module_getattr.<locals>.__getattr__(name)
#     224 if name in props:
#     225     return props[name].__get__(instance)
# --> 226 raise AttributeError(
#     227     f"module {cls.__module__!r} has no attribute {name!r}")
#
# AttributeError: module 'matplotlib' has no attribute 'pie'

# %%
import matplotlib.pyplot as plt

# %%
age_group_sales = d.groupby('Age_Group', as_index=False)['Amount'].sum()

# %%
plt.pie(age_group_sales['Amount'], autopct='%1.2f%%', labels=age_group_sales['Age_Group'], startangle=200, colors=plt.cm.Paired.colors)
plt.title('Total Amount by Age Group')
plt.figure(figsize=(8, 8))
wedgeprops={'edgecolor': 'white', 'linewidth': 10}
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
d
# Out:
#        User_ID  Product_ID  Gender  Age_Group  Age  Marital_Status  State  \
# 0         1780         774       0          2   16               0     10
# 1          456         644       0          2   23               1      0
# 2         1226         714       0          2   23               1     14
# 3          890        1507       1          0    4               0      7
# 4          371         387       1          2   16               1      3
# ...        ...         ...     ...        ...  ...             ...    ...
# 11246      431        1888       1          1    7               1     10
# 11247     2536        1039       1          2   21               0      4
# 11248      749        1263       0          3   28               0      9
# 11249     2494         396       1          3   25               0      7
# 11250     1672        1786       0          1    7               0     10
#
#        Zone  Occupation  Orders  Amount
# ...
